# %%
"""
DocString:" The legend of zelda: retreiving the Master Sword"
    
    A) Introduction:
    
    This game is a quest from the Legend of Zelda, where the young champion of
    Hyrule needs to retrieve the Master Sword, that according to the legend 
    is located in the Lost Woods, to succed the young champion needs to pass 
    the trials given to him.
    
    Hyrule Castle: The king is looking for the young champion of the legend;
                    introduce yourself and answer his questions.
                    
    Entrance of the Lost Woods: A test of Valor awaits, throw your dice (20 sided) to 
                                prove to the guardian of the woods you deserve to go to
                                the next stage;if you are not worthy you will lost the game.
                                
    Mo'a Keet shrine :You need to complete 20 exact steps while rolling the dices
                    6 sides will get you up the steps and the 4 sides will get you down, going
                    over 20 steps will make you lose the game.
                     

    B) Known Bugs and/or Errors:
    none
"""

# calling random, exit and pandas funcionts functions
from sys import exit
import random 
import pandas as pd
from colorama import Fore, Back, Style
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

def start():
    
    print(Fore.GREEN+"""


 _                               _          __   ______     _     _       
| |                             | |        / _| |___  /    | |   | |      
| |     ___  __ _  ___ _ __   __| |   ___ | |_     / /  ___| | __| | __ _ 
| |    / _ \/ _` |/ _ | '_ \ / _` |  / _ \|  _|   / /  / _ | |/ _` |/ _` |
| |___|  __| (_| |  __| | | | (_| | | (_) | |   ./ /__|  __| | (_| | (_| |
\_____/\___|\__, |\___|_| |_|\__,_|  \___/|_|   \_____/\___|_|\__,_|\__,_|
             __/ |                                                        
            |___/                                                         

""")
    print(Fore.GREEN + f"""
    {'-' * 40}

    Introduction:
    King Johan of Hyrule received a terrible message from the appointed Knight of 
    Princess Zelda. She is trapped in her tower by the power of Malice Ganon, and only 
    the divine light of the Master Sword, capable of destroying darkness and repelling evil, 
    will free her.
    However only the Choosen Champion is worthy to retrieve and wield the sword.

    King Johan starts his journey to find this Champion.. when He suddnely approaches you

    {'-' * 40}\n""")
    
    input(prompt="<Press Enter to Continue>")
    hyrule_castle()

#We build the first stage on Hyrule Castle, you will introduce yourself 
#to the king and base on some question he will determine if you are the champion
#who can save the pricess

def hyrule_castle():  #first stage of the game 
    #introduce yourself to the king
    name= input(prompt="What's your name?: ")
    city= input(prompt="What's your village?: ")
    profession= input (prompt="What's your profession?: ")
    
    if name=='' or city == '' or profession=='':
        print("\n Young Hero, please introduce yourself to the king") #if you dont introduce anything you restart
        hyrule_castle()
     # the king ask question to the champion to define if he is the chosen one 
    print(f"""
    Welcome Young Hero {name} from {city} village. Your courage and Value
    as a {profession} is known in many villages and across the kingdom I seek
    your help but first I need to know if you are the choosen one. Answer these
    questions for me to prove your valor.
    """)
    # he asks what is the weapon he prefers
    weapon= input(prompt="\n Would you prefer to use : a sword, magic or a bow: ")
    #if the answer is wrong he is not the chosen one and the game ends
    if weapon.lower()== 'sword' or weapon.lower()=='bow':
        
        #if the answer is wrong he is not the chosen one and the game ends
        valor=input(prompt="\n If you meet a traveler being attacked will you help or walk away?: ")
        if valor.lower()== 'help':
            print("\n Good Answer young hero, one last question ")
        
        #if the answer is wrong he is not the chosen one and the game ends
            peace=input(prompt="\n If you have the most powerful weapon will you destroy your enemies or keep balance?: ")
            
            if peace.lower()=='keep balance' or peace.lower()=='balance':
                print(f""""
    You {name} from  {city} are the lengedary champion the choosen one to wield the Master sword\n
                """ )
                
                quest=input(prompt="""Would you like to start the quest to retrieve the legendary sword and save the princess?(yes/no) """)
                if quest.lower()=="yes" or quest.lower()=="y":
                    lost_woods()
         #the wrong answer will make you lost your chance and you will need to restar again        
                else:
                     lost_game()
            else: 
                print (f"""\n 
                Sorry young {name} you are not the choosen champion, I will continue my search""")
                hyrule_castle()
            
        else:
            print (f"""\n 
            Sorry young {name} you are not the choosen champion, I will continue my search""")
            hyrule_castle()
    else:
        print (f"""\n 
        Sorry young {name} you are not the choosen champion, I will continue my search""")
        hyrule_castle() #the game resets and the king search for a new champion

        
def lost_woods(): #secon stage of the game:looking for the master sword
    print(Fore.GREEN+f""" 
    {'-' * 40}
    
    You make your way through the Great Plateau on your horse and see The Darkness 
    consuming the Kingdom. Without The Light of Princess Zelda, Hyrule will fall under Ganon.... 
    Suddenly, you see towering trees and reach the entrance of the Lost Woods. Here, you find a 
    small creature called a Korok in yout search for the Master Sword.

    {'-' * 40}\n""")
   
    input(prompt="<Press Enter to Continue>")
    traveler=''
    while traveler=='':
        traveler=input(prompt="\n What's your name traveler:  ")
    sword=''
    while sword=='':
        sword= input(prompt=f" \n Welcome to the Lost Woods {traveler}, what is that you seek? \n")
    #the game wont continue unless you introduce yourself and say the reason of your presence 
    sword2="master sword"

    while sword.lower() not in sword2: #until you don't mention the word sword the game won't continue
        sword= input(prompt="I don't know about that, however there is a treasure waiting for the chosen one , what is that you seek? \n ") 
    
    print(f"""\n Great Hero of Hyrule if the {sword} is what you seek I can help you, but first I need to prove your
    Courage and Wisdom.""")
    input(prompt="<Press Enter to Continue>")
    print(f"""
    \n
     You will have 3 chances to prove your  Courage and Wisdom. First throw this icosahedron. 
     With the Goddess Hylia’s blessing you will pass the trial. 
     If not, you will never be able to find this place again.\n""")
    #the dice will be thrwon 3 times if the number if between 20 and 15 you will be granted inmediately acces to 
    #the dungeon where the sword is located
    # between 15-10 you will need to solve a puzzle 
    #between  0-5 you authomatically lose the game 
    opportunities =3 #opportunities to throw the dice 
     
    while opportunities >0:
        opportunities=opportunities-1
        roll = random.randint(0, 20) 
        input(prompt="  ")
        
        if roll >=15: # if you roll a number over 15 you authomaticall win
            print(f"""\n You roll a {roll} which shows a high wisdom and courage""")
            printmd("**Your Courage and Wisdom were confirmed by the Goodess. You are worthy to enter the Shrine**")
            input(prompt=("Press any key to continue to the Shrine"))
            shirne()
        
        elif (roll<15) and (roll >5): #if you roll between 5 and 15 you need to do an additional trial
            printmd(f"""**\n You roll a {roll} you need to train more to prove your valor**""")
            printmd(f"""
        You must complete and additional trial to prove your value, resolve this riddle, you have 3 opportunities: 
        {'-' * 40}\n
        "Small, red, round, and sweet!
        Bring me one of this simple treat!"
        Once you know the answer, tell me what it is!
        {'-' * 40}\n """)
            chances=3 #opportunities to solve the riddle counting 
            answer="apple"
            riddle=input(prompt=(f"""
            \n Traveler you know the answer or do you need a hint (enter Hint for hint)\n"""))
          #The hero is given a riddle and the opportunity of getting a hint if he answers right
          # he will get the chance to get into the shirne
            while chances > 0:
                if riddle.lower()== answer: #compare the first answer if it is right the hero goes into the shrine
                    printmd("**Your Courage and Wisdom were confirmed by the Goodess. You are worthy to enter the Shrine**")
                    input(prompt=("Press any key to continue to the Shrine")) 
                    shirne()
                elif riddle.lower()=="hint": # the hero can take only one hint it counts as an opportunity   
                    print("your hint is : Issac Newton was inspired by an ____\n ")
                    riddle= input(prompt=(f"""enter your answer?\n"""))  
        
                    if riddle.lower()== answer: #if the hero gueeses the answer he will go to the next stage
                        printmd("**Your Courage and Wisdom were confirmed by the Goodess. You are worthy to enter the Shrine**")
                        input(prompt=("Press any key to continue to the Shrine")) 
                        shirne()
                else:
                    riddle= input(prompt=(f"""{riddle} was not the answer try again\n"""))
                chances= chances-1
          
            if (chances ==0) and (opportunities !=0): # if you run out of answers you get the chance to throw the dice one more time                                                  
                    #If you still have more opportunities left 
                print("Goddess Hylia will grant you one more chance to prove your are the true hero")
                input(prompt='Press Any Key to throw again the dice')
            else:
                lost_game() # if the chances to answer and is not the last roll he can roll the dice again
                
        else:#if the rolled dice is less than 5 and is not the last opportunity he can roll again
            print(f"""\n\n You roll a {roll} you are not worthy on the presence of the goddess\n\n""")
            if opportunities==0:#if you have 3 low results in a row you  will lose the game 
                lost_game()
            else:
                print("Goddess Hylia will grant you one more chance to prove your are the true hero")
                input(prompt='Press Any Key to throw again the dice')
                
            
                  
def shirne(): #third and last stage of the game, completing this will win the game
       
    printmd("""**Mo'a Keet shrine**""" )
    print(Fore.GREEN+ f"""    
    Welcome to the Mo'a Keet Shrine. You proved your worthiness and your presence in this 
    land of tribulation shows that you are the great hero of Hyrule, however there is one 
    last trial to overcome to retrieve the Master Sword""")
    
    print(f"""    
    To overcome this challenge and become the champion of the legend you need to survive
    the labyrinth. You will need a 4 and 6 sided dice, the 6 sided will add to your steps 
    while the 4 sided will rest them. You will need a total of 20 steps to get throguh here.
    If you go over 20 you will lost and your memories of this place will be erase""")
    
    start_challenge=input(prompt="\n Are you ready to start the challenge Y/N: ") #if you optout you will lost the game
    
    if start_challenge.lower()=='yes' or start_challenge.lower()=='y':
        steps=0 # you start at step 0 , no engative steps

        while steps < 20: #we need to reach a total of 20 steps, we make a loop to roll the dice as many times as needed
            sides=input(prompt="\nWhich dice you want to throw 4 or 6:")
            if sides== "4": # 4 side dice will rest steps
                dice = random.randint(1,4)
                if steps<=4: #if the steps are less than 4, and throw the dice 4, we always get 0 steps (no negative steps)
                    steps=0
                    print(f"""You rolled: {dice} """)
                    print(f"""Your steps are: {steps} """)
                else:# after each roll we rest as many steps as the rolled number
                    steps= steps - dice
                    print(f"""You rolled : {dice} """)
                    print(f"""Your steps are: {steps} """)
           
            elif sides== "6": #will increase the steps  
                dice = random.randint(1,6)
                steps= steps + dice   #after each roll we add as many steps as the rolled number                
                print(f"""You rolled: {dice} """)
                print(f"""Your steps are: {steps} """)
            else:
                print("You introduce a non valid number")
                #sides=input(prompt="Which dice you want to throw 4 or 6: \n")
        if steps ==20: #if you hit 20 steps you win the game and retrieve the master sword        
            master_sword='Congratulations you got the Master Sword'
            print("\n" )
            for leter in master_sword:
                print(leter,end=' ')
            print(f"""
            \n You are the Champion of the Legend by retrieving the Master Sword and wielding its power
            Now you must return to King Johan at Hyrule Castle and save Princess Zelda\n """)
    
            printmd("""**YOU WON THE GAME**""" )
            restart= input(prompt="Would you like to start again Y/N?: ")# you can choose to restart the game
            if restart.lower()== 'y' or restart.lower()=='yes':
                hyrule_castle()
            else:
                start_game_shrine=input(prompt="\n Thanks for playing press enter to restart the game  ")#you quit a restart form the begining
                start()
                
        else:
            print("You lost your memories, Hyrule will be consumed by Darkness")#you fail the stage and have the chance to play again this stage
            restart_shrine=input(prompt=""""Would you like to try one more time?:(Y/N) \n""")# if you say no you will quit the game 
            if  restart_shrine.lower() == "yes" or restart_shrine.lower() =="y":
                shirne()
            else:
                lost_game()
    else:
        lost_game()
    
    
#whenever the player loses or quits the game this message apperas, and gives the option to restart the game or quit
def lost_game():
    print("\n Princess Zelda was consumed by The Darkness and Hyrule has fallen under Ganon's Power")
    restart= input(prompt="Would youlike to start again Y/N?: ")
    if restart.lower()== 'y' or restart.lower()=='yes':
        hyrule_castle()
    else:
        print(""""\n Thanks for playing press enter to quit """)
        start_game_lost=input(prompt="  ")
        start()

start()
# Out:
#  _                               _          __   ______     _     _
# | |                             | |        / _| |___  /    | |   | |
# | |     ___  __ _  ___ _ __   __| |   ___ | |_     / /  ___| | __| | __ _
# | |    / _ \/ _` |/ _ | '_ \ / _` |  / _ \|  _|   / /  / _ | |/ _` |/ _` |
# | |___|  __| (_| |  __| | | | (_| | | (_) | |   ./ /__|  __| | (_| | (_| |
# \_____/\___|\__, |\___|_| |_|\__,_|  \___/|_|   \_____/\___|_|\__,_|\__,_|
#              __/ |
#             |___/
#
#
#
#     ----------------------------------------
#
#     Introduction:
#     King Johan of Hyrule received a terrible message from the appointed Knight of
#     Princess Zelda. She is trapped in her tower by the power of Malice Ganon, and only
#     the divine light of the Master Sword, capable of destroying darkness and repelling evil,
#     will free her.
#     However only the Choosen Champion is worthy to retrieve and wield the sword.
#
# ...
